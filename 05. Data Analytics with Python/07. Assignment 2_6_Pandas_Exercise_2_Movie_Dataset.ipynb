# %% [markdown]
# ## Practice Exercise 2

# %% [markdown]
# In this assignment, you will try to find some interesting insights into a few movies released between 1916 and 2016, using Python. You will have to download a movie dataset, write Python code to explore the data, gain insights into the movies, actors, directors, and collections, and submit the code.

# %% [markdown]
# #### Some tips before starting the assignment
#
# 1. Identify the task to be performed correctly, and only then proceed to write the required code. Don’t perform any incorrect analysis or look for information that isn’t required for the assignment.
# 2. In some cases, the variable names have already been assigned, and you just need to write code against them. In other cases, the names to be given are mentioned in the instructions. We strongly advise you to use the mentioned names only.
# 3. Always keep inspecting your data frame after you have performed a particular set of operations.
# 4. There are some checkpoints given in the IPython notebook provided. They're just useful pieces of information you can use to check if the result you have obtained after performing a particular task is correct or not.
# 5. Note that you will be asked to refer to documentation for solving some of the questions. That is done on purpose for you to learn new commands and also how to use the documentation.

# %%
# Import the numpy and pandas packages

import numpy as np
import pandas as pd

# %% [markdown]
# ### Task 1: Reading and Inspection
#
# **Subtask 1.1: Import and read**
#
# Import and read the movie database. Store it in a variable called `movies`.

# %%
# Write your code for importing the csv file here
movies = pd.read_csv('C:/Users/farina/Documents/work/training/14. CADS/05. Data Analytics with Python/Assignmnts/07. Assignment 2_6_Movies.csv')
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 3848  Color      Shane Carruth                   143.0      77.0
# 3849  Color   Neill Dela Llana                    35.0      80.0
# 3850  Color   Robert Rodriguez                    56.0      81.0
# 3851  Color       Edward Burns                    14.0      95.0
# 3852  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 0                         0.0                   855.0    Joel David Moore
# 1                       563.0                  1000.0       Orlando Bloom
# 2                         0.0                   161.0        Rory Kinnear
# 3                     22000.0                 23000.0      Christian Bale
# 4                       475.0                   530.0     Samantha Morton
# ...                       ...                     ...                 ...
# 3848                    291.0                     8.0      David Sullivan
# 3849                      0.0                     0.0     Edgar Tancangco
# 3850                      0.0                     6.0     Peter Marquardt
# 3851                      0.0                   133.0  Caitlin FitzGerald
# 3852                     16.0                    16.0    Brian Herzlinger
#
#       actor_1_facebook_likes        gross  \
# 0                     1000.0  760505847.0
# 1                    40000.0  309404152.0
# 2                    11000.0  200074175.0
# 3                    27000.0  448130642.0
# 4                      640.0   73058679.0
# ...                      ...          ...
# 3848                   291.0     424760.0
# 3849                     0.0      70071.0
# 3850                   121.0    2040920.0
# 3851                   296.0       4584.0
# 3852                    86.0      85222.0
#
#                                    genres  ... num_user_for_reviews language  \
# 0         Action|Adventure|Fantasy|Sci-Fi  ...               3054.0  English
# 1                Action|Adventure|Fantasy  ...               1238.0  English
# 2               Action|Adventure|Thriller  ...                994.0  English
# 3                         Action|Thriller  ...               2701.0  English
# 4                 Action|Adventure|Sci-Fi  ...                738.0  English
# ...                                   ...  ...                  ...      ...
# 3848                Drama|Sci-Fi|Thriller  ...                371.0  English
# 3849                             Thriller  ...                 35.0  English
# 3850  Action|Crime|Drama|Romance|Thriller  ...                130.0  Spanish
# 3851                         Comedy|Drama  ...                 14.0  English
# 3852                          Documentary  ...                 84.0  English
#
#           country  content_rating       budget  title_year  \
# 0             USA           PG-13  237000000.0      2009.0
# 1             USA           PG-13  300000000.0      2007.0
# 2              UK           PG-13  245000000.0      2015.0
# 3             USA           PG-13  250000000.0      2012.0
# 4             USA           PG-13  263700000.0      2012.0
# ...           ...             ...          ...         ...
# 3848          USA           PG-13       7000.0      2004.0
# 3849  Philippines       Not Rated       7000.0      2005.0
# 3850          USA               R       7000.0      1992.0
# 3851          USA       Not Rated       9000.0      2011.0
# 3852          USA              PG       1100.0      2004.0
#
#      actor_2_facebook_likes imdb_score  aspect_ratio movie_facebook_likes
# 0                     936.0        7.9          1.78                33000
# 1                    5000.0        7.1          2.35                    0
# 2                     393.0        6.8          2.35                85000
# 3                   23000.0        8.5          2.35               164000
# 4                     632.0        6.6          2.35                24000
# ...                     ...        ...           ...                  ...
# 3848                   45.0        7.0          1.85                19000
# 3849                    0.0        6.3           NaN                   74
# 3850                   20.0        6.9          1.37                    0
# 3851                  205.0        6.4           NaN                  413
# 3852                   23.0        6.6          1.85                  456
#
# [3853 rows x 28 columns]

# %% [markdown]
# **Subtask 1.2: Inspect the dataframe**
#
# Inspect the dataframe's columns, shapes, variable types etc.

# %%
# Write your code for inspection here
print(movies.columns)
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
print(movies.shape)
# Out:
# (3853, 28)

# %%
print(movies.dtypes)
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# imdb_score                   float64
# aspect_ratio                 float64
# movie_facebook_likes           int64
# dtype: object

# %%
print(movies.describe())
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             3852.000000  3852.000000              3853.000000
# mean               163.046989   109.921080               784.507397
# std                123.927258    22.741728              3027.395958
# min                  1.000000    34.000000                 0.000000
# 25%                 72.000000    95.000000                10.000000
# 50%                134.000000   106.000000                58.000000
# 75%                221.000000   120.000000               222.000000
# max                813.000000   330.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             3847.000000             3853.000000  3.853000e+03
# mean               747.290096             7575.558526  5.096547e+07
# std               1841.623945            15405.383114  6.932033e+07
# min                  0.000000                0.000000  1.620000e+02
# 25%                183.000000              721.000000  6.830957e+06
# 50%                427.000000             1000.000000  2.790000e+07
# 75%                685.000000            12000.000000  6.550000e+07
# max              23000.000000           640000.000000  7.605058e+08
#
#        num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# count     3.853000e+03                3853.000000           3847.000000
# mean      1.024240e+05               11239.480145              1.378217
# std       1.502942e+05               18922.948757              2.056071
# min       5.000000e+00                   0.000000              0.000000
# 25%       1.730900e+04                1817.000000              0.000000
# 50%       5.052300e+04                3876.000000              1.000000
# 75%       1.241850e+05               15972.000000              2.000000
# max       1.689764e+06              656730.000000             43.000000
#
#        num_user_for_reviews        budget   title_year  \
# count           3853.000000  3.853000e+03  3853.000000
# mean             326.720478  4.524817e+07  2003.061511
# std              407.920904  2.234208e+08    10.007168
# min                1.000000  2.180000e+02  1920.000000
# 25%              102.000000  1.000000e+07  1999.000000
# 50%              203.000000  2.400000e+07  2005.000000
# 75%              391.000000  5.000000e+07  2010.000000
# max             5060.000000  1.221550e+10  2016.000000
#
#        actor_2_facebook_likes   imdb_score  aspect_ratio  movie_facebook_likes
# count             3852.000000  3853.000000   3781.000000           3853.000000
# mean              1959.018432     6.462886      2.109569           9089.546068
# std               4472.171290     1.053843      0.353236          21277.375223
# min                  0.000000     1.600000      1.180000              0.000000
# 25%                362.000000     5.900000      1.850000              0.000000
# 50%                664.000000     6.600000      2.350000            206.000000
# 75%                971.000000     7.200000      2.350000          11000.000000
# max             137000.000000     9.300000     16.000000         349000.000000

# %% [markdown]
# #### <font color='red'>Question 1: How many rows and columns are present in the dataframe? </font>
# -  <font color='red'>(3821, 26)</font>
# -  <font color='red'>(3879, 28)</font>
# -  <font color='red'>(3853, 28)</font>
# -  <font color='red'>(3866, 26)</font>

# %%
## Write your code here
print(movies.shape)
# Out:
# (3853, 28)

# %% [markdown]
# #### <font color='red'>Question 2: How many columns have null values present in them? Try writing a code for this instead of counting them manually.</font>
#
# -  <font color='red'>3</font>
# -  <font color='red'>6</font>
# -  <font color='red'>9</font>
# -  <font color='red'>12</font>

# %%
## Write your code here
print ("Columns with null values : ", movies.isnull().any().sum())
print("Columns with null values: ", movies.columns[movies.isna().any()])
# Out:
# Columns with null values :  12
# Columns with null values:  Index(['color', 'num_critic_for_reviews', 'duration', 'actor_3_facebook_likes',
#        'actor_2_name', 'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'language', 'content_rating', 'actor_2_facebook_likes', 'aspect_ratio'],
#       dtype='object')

# %% [markdown]
# ### Task 2: Cleaning the Data
#
# **Subtask 2.1: Drop unecessary columns**
#
# For this assignment, you will mostly be analyzing the movies with respect to the ratings, gross collection, popularity of movies, etc. So many of the columns in this dataframe are not required. So it is advised to drop the following columns.
# -  color
# -  director_facebook_likes
# -  actor_1_facebook_likes
# -  actor_2_facebook_likes
# -  actor_3_facebook_likes
# -  actor_2_name
# -  cast_total_facebook_likes
# -  actor_3_name
# -  duration
# -  facenumber_in_poster
# -  content_rating
# -  country
# -  movie_imdb_link
# -  aspect_ratio
# -  plot_keywords

# %%
# Check the 'drop' function in the Pandas library - dataframe.drop(list_of_unnecessary_columns, axis = )
# Write your code for dropping the columns here. It is advised to keep inspecting the dataframe after each set of operations

new_movies = movies.drop(columns = ['color','director_facebook_likes','actor_1_facebook_likes','actor_2_facebook_likes', 
                                    'actor_3_facebook_likes', 'actor_2_name','cast_total_facebook_likes', 'actor_3_name',
                                    'duration', 'facenumber_in_poster','content_rating','country','movie_imdb_link',
                                    'aspect_ratio','plot_keywords'], axis = 1)

# %%
new_movies.head()
# Out:
#        director_name  num_critic_for_reviews        gross  \
# 0      James Cameron                   723.0  760505847.0
# 1     Gore Verbinski                   302.0  309404152.0
# 2         Sam Mendes                   602.0  200074175.0
# 3  Christopher Nolan                   813.0  448130642.0
# 4     Andrew Stanton                   462.0   73058679.0
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4          Action|Adventure|Sci-Fi     Daryl Sabara
#
#                                  movie_title  num_voted_users  \
# 0                                    Avatar            886204
# 1  Pirates of the Caribbean: At World's End            471220
# 2                                   Spectre            275868
# 3                     The Dark Knight Rises           1144337
# 4                               John Carter            212204
#
#    num_user_for_reviews language       budget  title_year  imdb_score  \
# 0                3054.0  English  237000000.0      2009.0         7.9
# 1                1238.0  English  300000000.0      2007.0         7.1
# 2                 994.0  English  245000000.0      2015.0         6.8
# 3                2701.0  English  250000000.0      2012.0         8.5
# 4                 738.0  English  263700000.0      2012.0         6.6
#
#    movie_facebook_likes
# 0                 33000
# 1                     0
# 2                 85000
# 3                164000
# 4                 24000

# %% [markdown]
# #### <font color='red'>Question 3: What is the count of columns in the new dataframe? </font>
# -  <font color='red'>10</font>
# -  <font color='red'>13</font>
# -  <font color='red'>15</font>
# -  <font color='red'>17</font>

# %%
## Write your code here
print("Number of Columns : ", new_movies.shape[1])
# Out:
# Number of Columns :  13

# %% [markdown]
# **Subtask 2.2: Inspect Null values**
#
# As you have seen above, there are null values in multiple columns of the dataframe 'movies'. Find out the percentage of null values in each column of the dataframe 'movies'.

# %%
# Write you code here
print ("Columns with null values_OldDataFrame : ", movies.isnull().any().sum())
print ("Columns with null values_NewDataFrame : ", new_movies.isnull().any().sum())
print ("Columns with null values_NewDataFrame : ", new_movies.columns[new_movies.isna().any()])
#[col for col in new_movies.columns if new_movies[col].isnull().any()]
# Out:
# Columns with null values_OldDataFrame :  12
# Columns with null values_NewDataFrame :  2
# Columns with null values_NewDataFrame :  Index(['num_critic_for_reviews', 'language'], dtype='object')

# %%
percentage_missingvalue_movies = movies.isnull().sum()*100/len(movies)
print (percentage_missingvalue_movies)
# Out:
# color                        0.051908
# director_name                0.000000
# num_critic_for_reviews       0.025954
# duration                     0.025954
# director_facebook_likes      0.000000
# actor_3_facebook_likes       0.155723
# actor_2_name                 0.025954
# actor_1_facebook_likes       0.000000
# gross                        0.000000
# genres                       0.000000
# actor_1_name                 0.000000
# movie_title                  0.000000
# num_voted_users              0.000000
# cast_total_facebook_likes    0.000000
# actor_3_name                 0.155723
# facenumber_in_poster         0.155723
# plot_keywords                0.778614
# movie_imdb_link              0.000000
# num_user_for_reviews         0.000000
# language                     0.077861
# country                      0.000000
# content_rating               1.245783
# budget                       0.000000
# title_year                   0.000000
# actor_2_facebook_likes       0.025954
# imdb_score                   0.000000
# aspect_ratio                 1.868674
# movie_facebook_likes         0.000000
# dtype: float64

# %%
percentage_missingvalue_newmovies = new_movies.isnull().sum()*100/len(new_movies)
print (percentage_missingvalue_newmovies)
# Out:
# director_name             0.000000
# num_critic_for_reviews    0.025954
# gross                     0.000000
# genres                    0.000000
# actor_1_name              0.000000
# movie_title               0.000000
# num_voted_users           0.000000
# num_user_for_reviews      0.000000
# language                  0.077861
# budget                    0.000000
# title_year                0.000000
# imdb_score                0.000000
# movie_facebook_likes      0.000000
# dtype: float64

# %% [markdown]
# #### <font color='red'>Question 4: Which column has the highest percentage of null values? </font>
# -  <font color='red'>language</font>
# -  <font color='red'>genres</font>
# -  <font color='red'>num_critic_for_reviews</font>
# -  <font color='red'>imdb_score</font>

# %%
## Write your code here
percentage_missingvalue_newmovies.sort_values(ascending=False)
# Out:
# language                  0.077861
# num_critic_for_reviews    0.025954
# director_name             0.000000
# gross                     0.000000
# genres                    0.000000
# actor_1_name              0.000000
# movie_title               0.000000
# num_voted_users           0.000000
# num_user_for_reviews      0.000000
# budget                    0.000000
# title_year                0.000000
# imdb_score                0.000000
# movie_facebook_likes      0.000000
# dtype: float64

# %% [markdown]
# **Subtask 2.3: Fill NaN values**
#
# You might notice that the `language` column has some NaN values. Here, on inspection, you will see that it is safe to replace all the missing values with `'English'`.

# %%
# Write your code for filling the NaN values in the 'language' column here

new_movies["language"].fillna("English", inplace = True)

# %% [markdown]
# #### <font color='red'>Question 5: What is the count of movies made in English language after replacing the NaN values with English? </font>
# -  <font color='red'>3670</font>
# -  <font color='red'>3674</font>
# -  <font color='red'>3668</font>
# -  <font color='red'>3672</font>

# %%
## Write your code here
print ("No of English movies: ", new_movies['language'].value_counts().English)
# Out:
# No of English movies:  3674

# %% [markdown]
# ### Task 3: Data Analysis
#
# **Subtask 3.1: Change the unit of columns**
#
# Convert the unit of the `budget` and `gross` columns from `$` to `million $`.

# %%
## Write your code here
def to_million(x):
    return x / 1000000
new_movies.budget = new_movies.budget.apply(to_million)

# %%
def to_million(y):
    return y / 1000000
new_movies.gross = new_movies.gross.apply(to_million)

# %%
new_movies.head()
# Out:
#        director_name  num_critic_for_reviews       gross  \
# 0      James Cameron                   723.0  760.505847
# 1     Gore Verbinski                   302.0  309.404152
# 2         Sam Mendes                   602.0  200.074175
# 3  Christopher Nolan                   813.0  448.130642
# 4     Andrew Stanton                   462.0   73.058679
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4          Action|Adventure|Sci-Fi     Daryl Sabara
#
#                                  movie_title  num_voted_users  \
# 0                                    Avatar            886204
# 1  Pirates of the Caribbean: At World's End            471220
# 2                                   Spectre            275868
# 3                     The Dark Knight Rises           1144337
# 4                               John Carter            212204
#
#    num_user_for_reviews language  budget  title_year  imdb_score  \
# 0                3054.0  English   237.0      2009.0         7.9
# 1                1238.0  English   300.0      2007.0         7.1
# 2                 994.0  English   245.0      2015.0         6.8
# 3                2701.0  English   250.0      2012.0         8.5
# 4                 738.0  English   263.7      2012.0         6.6
#
#    movie_facebook_likes
# 0                 33000
# 1                     0
# 2                 85000
# 3                164000
# 4                 24000

# %% [markdown]
# **Subtask 3.2: Find the movies with highest profit**
#
#    1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
#    2. Sort the dataframe using the `profit` column as reference. (Find which command can be used here to sort entries from the documentation)
#    3. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`

# %%
# Write your code for creating the profit column here
new_movies['profit'] = new_movies['gross'] - new_movies['budget']
new_movies.head()
# Out:
#        director_name  num_critic_for_reviews       gross  \
# 0      James Cameron                   723.0  760.505847
# 1     Gore Verbinski                   302.0  309.404152
# 2         Sam Mendes                   602.0  200.074175
# 3  Christopher Nolan                   813.0  448.130642
# 4     Andrew Stanton                   462.0   73.058679
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4          Action|Adventure|Sci-Fi     Daryl Sabara
#
#                                  movie_title  num_voted_users  \
# 0                                    Avatar            886204
# 1  Pirates of the Caribbean: At World's End            471220
# 2                                   Spectre            275868
# 3                     The Dark Knight Rises           1144337
# 4                               John Carter            212204
#
#    num_user_for_reviews language  budget  title_year  imdb_score  \
# 0                3054.0  English   237.0      2009.0         7.9
# 1                1238.0  English   300.0      2007.0         7.1
# 2                 994.0  English   245.0      2015.0         6.8
# 3                2701.0  English   250.0      2012.0         8.5
# 4                 738.0  English   263.7      2012.0         6.6
#
#    movie_facebook_likes      profit
# 0                 33000  523.505847
# 1                     0    9.404152
# 2                 85000  -44.925825
# 3                164000  198.130642
# 4                 24000 -190.641321

# %%
# Write your code for sorting the dataframe here
new_movies = new_movies.sort_values (by = 'profit',axis = 0, ascending = False, inplace=False)
new_movies
# Out:
#          director_name  num_critic_for_reviews       gross  \
# 0        James Cameron                   723.0  760.505847
# 28     Colin Trevorrow                   644.0  652.177271
# 25       James Cameron                   315.0  658.672302
# 2704      George Lucas                   282.0  460.935665
# 2748  Steven Spielberg                   215.0  434.949459
# ...                ...                     ...         ...
# 2147   Katsuhiro Ôtomo                   105.0    0.410388
# 2136    Hayao Miyazaki                   174.0    2.298191
# 2693      Lajos Koltai                    73.0    0.195888
# 3282    Chan-wook Park                   202.0    0.211667
# 2678      Joon-ho Bong                   363.0    2.201412
#
#                                                  genres         actor_1_name  \
# 0                       Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 28                     Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 25                                        Drama|Romance    Leonardo DiCaprio
# 2704                    Action|Adventure|Fantasy|Sci-Fi        Harrison Ford
# 2748                                      Family|Sci-Fi         Henry Thomas
# ...                                                 ...                  ...
# 2147  Action|Adventure|Animation|Family|Sci-Fi|Thriller     William Hootkins
# 2136                        Adventure|Animation|Fantasy        Minnie Driver
# 2693                                  Drama|Romance|War         Marcell Nagy
# 3282                                        Crime|Drama         Min-sik Choi
# 2678                         Comedy|Drama|Horror|Sci-Fi            Doona Bae
#
#                               movie_title  num_voted_users  \
# 0                                 Avatar            886204
# 28                        Jurassic World            418214
# 25                               Titanic            793059
# 2704  Star Wars: Episode IV - A New Hope            911097
# 2748          E.T. the Extra-Terrestrial            281842
# ...                                   ...              ...
# 2147                            Steamboy             13727
# 2136                   Princess Mononoke            221552
# 2693                            Fateless              5603
# 3282                      Lady Vengeance             53508
# 2678                            The Host             68883
#
#       num_user_for_reviews   language        budget  title_year  imdb_score  \
# 0                   3054.0    English    237.000000      2009.0         7.9
# 28                  1290.0    English    150.000000      2015.0         7.0
# 25                  2528.0    English    200.000000      1997.0         7.7
# 2704                1470.0    English     11.000000      1977.0         8.7
# 2748                 515.0    English     10.500000      1982.0         7.9
# ...                    ...        ...           ...         ...         ...
# 2147                  79.0   Japanese   2127.519898      2004.0         6.9
# 2136                 570.0   Japanese   2400.000000      1997.0         8.4
# 2693                  45.0  Hungarian   2500.000000      2005.0         7.1
# 3282                 131.0     Korean   4200.000000      2005.0         7.7
# 2678                 279.0     Korean  12215.500000      2006.0         7.0
#
#       movie_facebook_likes        profit
# 0                    33000    523.505847
# 28                  150000    502.177271
# 25                   26000    458.672302
# 2704                 33000    449.935665
# 2748                 34000    424.449459
# ...                    ...           ...
# 2147                   973  -2127.109510
# 2136                 11000  -2397.701809
# 2693                   607  -2499.804112
# 3282                  4000  -4199.788333
# 2678                  7000 -12213.298588
#
# [3853 rows x 14 columns]

# %%
#top10 = # Write your code to get the top 10 profiting movies here

top10movies = new_movies.nlargest(10, 'profit', keep='first')
top10movies = top10movies[['movie_title','profit']]
top10movies
# Out:
#                                      movie_title      profit
# 0                                        Avatar   523.505847
# 28                               Jurassic World   502.177271
# 25                                      Titanic   458.672302
# 2704         Star Wars: Episode IV - A New Hope   449.935665
# 2748                 E.T. the Extra-Terrestrial   424.449459
# 16                                 The Avengers   403.279547
# 482                               The Lion King   377.783777
# 230   Star Wars: Episode I - The Phantom Menace   359.544677
# 64                              The Dark Knight   348.316061
# 419                            The Hunger Games   329.999255

# %% [markdown]
# **Checkpoint:** You might spot two movies directed by `James Cameron` in the list.

# %% [markdown]
# #### <font color='red'>Question 6: Which movie is ranked 5th from the top in the list obtained? </font>
# -  <font color='red'>E.T. the Extra-Terrestrial</font>
# -  <font color='red'>The Avengers</font>
# -  <font color='red'>The Dark Knight</font>
# -  <font color='red'>Titanic</font>

# %%
## Write your code here
print ("The 5th ranked movie is : ",top10movies['movie_title'].iloc[4])
# Out:
# The 5th ranked movie is :  E.T. the Extra-Terrestrial

# %% [markdown]
# **Subtask 3.3: Find IMDb Top 200**
#
# Create a new dataframe `IMDb_Top_200` and store the top 200 movies with the highest IMDb Rating (corresponding to the column: `imdb_score`). Also make sure that for all of these movies, the `num_voted_users` is greater than 25,000.
#
# Also add a `Rank` column containing the values 1 to 200 indicating the ranks of the corresponding films.

# %%
# Write your code for extracting the top 200 movies as per the IMDb score here. Make sure that you store it in a new dataframe 
# and name that dataframe as 'IMDb_Top_200'

IMDb_Top_200 = new_movies.sort_values (by = 'imdb_score', ascending = False)
IMDb_Top_200 = IMDb_Top_200[IMDb_Top_200['num_voted_users'] > 25000]
IMDb_Top_200 = IMDb_Top_200.nlargest(200, 'imdb_score', keep='first')
IMDb_Top_200 ['Rank'] = range(1, 201)
IMDb_Top_200
# Out:
#              director_name  num_critic_for_reviews       gross  \
# 1795        Frank Darabont                   199.0   28.341469
# 3016  Francis Ford Coppola                   208.0  134.821952
# 64       Christopher Nolan                   645.0  533.316061
# 2543  Francis Ford Coppola                   149.0   57.300000
# 3607          Sergio Leone                   181.0    6.100000
# ...                    ...                     ...         ...
# 2310   Michel Hazanavicius                   576.0   44.667095
# 859       Steven Spielberg                   194.0  164.435221
# 3500     Richard Linklater                   211.0    5.792822
# 2618      Steven Spielberg                   385.0  260.000000
# 2608        Lars von Trier                   177.0    4.157491
#
#                            genres       actor_1_name  \
# 1795                  Crime|Drama     Morgan Freeman
# 3016                  Crime|Drama          Al Pacino
# 64    Action|Crime|Drama|Thriller     Christian Bale
# 2543                  Crime|Drama     Robert De Niro
# 3607                      Western     Clint Eastwood
# ...                           ...                ...
# 2310         Comedy|Drama|Romance      Bérénice Bejo
# 859         Biography|Crime|Drama  Leonardo DiCaprio
# 3500                Drama|Romance   Vernon Dobtcheff
# 2618     Adventure|Drama|Thriller       Roy Scheider
# 2608          Crime|Drama|Musical  Catherine Deneuve
#
#                           movie_title  num_voted_users  num_user_for_reviews  \
# 1795        The Shawshank Redemption           1689764                4144.0
# 3016                   The Godfather           1155770                2238.0
# 64                   The Dark Knight           1676169                4667.0
# 2543          The Godfather: Part II            790926                 650.0
# 3607  The Good, the Bad and the Ugly            503509                 780.0
# ...                               ...              ...                   ...
# 2310                      The Artist            190030                 583.0
# 859              Catch Me If You Can            525801                 667.0
# 3500                   Before Sunset            168398                 492.0
# 2618                            Jaws            412454                 962.0
# 2608              Dancer in the Dark             79330                 690.0
#
#      language  budget  title_year  imdb_score  movie_facebook_likes  \
# 1795  English    25.0      1994.0         9.3                108000
# 3016  English     6.0      1972.0         9.2                 43000
# 64    English   185.0      2008.0         9.0                 37000
# 2543  English    13.0      1974.0         9.0                 14000
# 3607  Italian     1.2      1966.0         8.9                 20000
# ...       ...     ...         ...         ...                   ...
# 2310  English    15.0      2011.0         8.0                 30000
# 859   English    52.0      2002.0         8.0                 15000
# 3500  English     2.7      2004.0         8.0                 13000
# 2618  English     8.0      1975.0         8.0                 21000
# 2608  English    12.8      2000.0         8.0                     0
#
#           profit  Rank
# 1795    3.341469     1
# 3016  128.821952     2
# 64    348.316061     3
# 2543   44.300000     4
# 3607    4.900000     5
# ...          ...   ...
# 2310   29.667095   196
# 859   112.435221   197
# 3500    3.092822   198
# 2618  252.000000   199
# 2608   -8.642509   200
#
# [200 rows x 15 columns]

# %% [markdown]
# #### <font color='red'>Question 7: Suppose movies are divided into 5 buckets based on the IMDb ratings: </font>
# -  <font color='red'>7.5 to 8</font>
# -  <font color='red'>8 to 8.5</font>
# -  <font color='red'>8.5 to 9</font>
# -  <font color='red'>9 to 9.5</font>
# -  <font color='red'>9.5 to 10</font>
#
# <font color = 'red'> Which bucket holds the maximum number of movies from *IMDb_Top_200*? </font>

# %%
## Write your code here
IMDb_Top_200['imdb_score'].value_counts()
# Out:
# 8.0    48
# 8.1    45
# 8.3    23
# 8.2    23
# 8.5    18
# 8.4    15
# 8.6     8
# 8.7     7
# 8.8     5
# 8.9     4
# 9.0     2
# 9.3     1
# 9.2     1
# Name: imdb_score, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.hist(IMDb_Top_200['imdb_score'], bins = 5, range = (7.5,10), edgecolor = 'black')
plt.show()

# %% [markdown]
# **Subtask 3.4: Find the critic-favorite and audience-favorite actors**
#
#    1. Create three new dataframes namely, `Meryl_Streep`, `Leo_Caprio`, and `Brad_Pitt` which contain the movies in which the actors: 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' are the lead actors. Use only the `actor_1_name` column for extraction. Also, make sure that you use the names 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' for the said extraction.
#    2. Append the rows of all these dataframes and store them in a new dataframe named `Combined`.
#    3. Group the combined dataframe using the `actor_1_name` column.
#    4. Find the mean of the `num_critic_for_reviews` and `num_user_for_review` and identify the actors which have the highest mean.

# %%
# Write your code for creating three new dataframes here
#Meryl_Streep = # Include all movies in which Meryl_Streep is the lead

Meryl_Streep = new_movies[(new_movies['actor_1_name'] == 'Meryl Streep')]
Meryl_Streep
# Out:
#        director_name  num_critic_for_reviews       gross  \
# 1322   David Frankel                   208.0  124.732962
# 1471  Sydney Pollack                    66.0   87.100000
# 1132     Nora Ephron                   252.0   94.125426
# 1514   David Frankel                   234.0   63.536011
# 392     Nancy Meyers                   187.0  112.703470
# 2500  Phyllida Lloyd                   331.0   29.959436
# 1784  Stephen Daldry                   174.0   41.597830
# 2793   Robert Altman                   211.0   20.338609
# 1038   Curtis Hanson                    42.0   46.815748
# 1563   Carl Franklin                    64.0   23.209440
# 1390  Robert Redford                   227.0   14.998070
#
#                                genres  actor_1_name  \
# 1322             Comedy|Drama|Romance  Meryl Streep
# 1471          Biography|Drama|Romance  Meryl Streep
# 1132          Biography|Drama|Romance  Meryl Streep
# 1514             Comedy|Drama|Romance  Meryl Streep
# 392              Comedy|Drama|Romance  Meryl Streep
# 2500          Biography|Drama|History  Meryl Streep
# 1784                    Drama|Romance  Meryl Streep
# 2793               Comedy|Drama|Music  Meryl Streep
# 1038  Action|Adventure|Crime|Thriller  Meryl Streep
# 1563                            Drama  Meryl Streep
# 1390               Drama|Thriller|War  Meryl Streep
#
#                     movie_title  num_voted_users  num_user_for_reviews  \
# 1322     The Devil Wears Prada            286178                 631.0
# 1471             Out of Africa             52339                 200.0
# 1132             Julie & Julia             79264                 277.0
# 1514              Hope Springs             34258                 178.0
# 392           It's Complicated             69860                 214.0
# 2500             The Iron Lady             82327                 350.0
# 1784                 The Hours            102123                 660.0
# 2793  A Prairie Home Companion             19655                 280.0
# 1038            The River Wild             32544                  69.0
# 1563            One True Thing              9283                 112.0
# 1390           Lions for Lambs             41170                 298.0
#
#      language  budget  title_year  imdb_score  movie_facebook_likes     profit
# 1322  English    35.0      2006.0         6.8                     0  89.732962
# 1471  English    31.0      1985.0         7.2                     0  56.100000
# 1132  English    40.0      2009.0         7.0                 13000  54.125426
# 1514  English    30.0      2012.0         6.3                     0  33.536011
# 392   English    85.0      2009.0         6.6                     0  27.703470
# 2500  English    13.0      2011.0         6.4                 18000  16.959436
# 1784  English    25.0      2002.0         7.6                     0  16.597830
# 2793  English    10.0      2006.0         6.8                   683  10.338609
# 1038  English    45.0      1994.0         6.3                     0   1.815748
# 1563  English    30.0      1998.0         7.0                   592  -6.790560
# 1390  English    35.0      2007.0         6.2                     0 -20.001930

# %%
#Leo_Caprio = # Include all movies in which Leo_Caprio is the lead

Leo_Caprio = new_movies[(new_movies['actor_1_name'] == 'Leonardo DiCaprio')]
Leo_Caprio
# Out:
#               director_name  num_critic_for_reviews       gross  \
# 25            James Cameron                   315.0  658.672302
# 94        Christopher Nolan                   642.0  292.568851
# 859        Steven Spielberg                   194.0  164.435221
# 283       Quentin Tarantino                   765.0  162.804648
# 173   Alejandro G. Iñárritu                   556.0  183.635922
# 431         Martin Scorsese                   490.0  127.968405
# 347         Martin Scorsese                   352.0  132.373442
# 49             Baz Luhrmann                   490.0  144.812796
# 3025           Baz Luhrmann                   490.0  144.812796
# 2484           Baz Luhrmann                   106.0   46.338728
# 1336        Randall Wallace                    83.0   56.876365
# 294         Martin Scorsese                   606.0  116.866727
# 1364         Clint Eastwood                   392.0   37.304950
# 246         Martin Scorsese                   267.0  102.608827
# 1909             Jerry Zaks                    45.0   12.782508
# 934             Danny Boyle                   118.0   39.778599
# 1046             Sam Mendes                   323.0   22.877808
# 1457              Sam Raimi                    63.0   18.636537
# 312         Martin Scorsese                   233.0   77.679638
# 608            Ridley Scott                   238.0   39.380442
# 293            Edward Zwick                   166.0   57.366262
#
#                                 genres       actor_1_name  \
# 25                       Drama|Romance  Leonardo DiCaprio
# 94    Action|Adventure|Sci-Fi|Thriller  Leonardo DiCaprio
# 859              Biography|Crime|Drama  Leonardo DiCaprio
# 283                      Drama|Western  Leonardo DiCaprio
# 173   Adventure|Drama|Thriller|Western  Leonardo DiCaprio
# 431                   Mystery|Thriller  Leonardo DiCaprio
# 347               Crime|Drama|Thriller  Leonardo DiCaprio
# 49                       Drama|Romance  Leonardo DiCaprio
# 3025                     Drama|Romance  Leonardo DiCaprio
# 2484                     Drama|Romance  Leonardo DiCaprio
# 1336                  Action|Adventure  Leonardo DiCaprio
# 294       Biography|Comedy|Crime|Drama  Leonardo DiCaprio
# 1364             Biography|Crime|Drama  Leonardo DiCaprio
# 246                    Biography|Drama  Leonardo DiCaprio
# 1909                             Drama  Leonardo DiCaprio
# 934           Adventure|Drama|Thriller  Leonardo DiCaprio
# 1046                     Drama|Romance  Leonardo DiCaprio
# 1457           Action|Thriller|Western  Leonardo DiCaprio
# 312                        Crime|Drama  Leonardo DiCaprio
# 608              Action|Drama|Thriller  Leonardo DiCaprio
# 293           Adventure|Drama|Thriller  Leonardo DiCaprio
#
#                     movie_title  num_voted_users  num_user_for_reviews  \
# 25                     Titanic            793059                2528.0
# 94                   Inception           1468200                2803.0
# 859        Catch Me If You Can            525801                 667.0
# 283           Django Unchained            955174                1193.0
# 173               The Revenant            406020                1188.0
# 431             Shutter Island            786092                 964.0
# 347               The Departed            873649                2054.0
# 49            The Great Gatsby            362912                 753.0
# 3025          The Great Gatsby            362933                 753.0
# 2484            Romeo + Juliet            167750                 506.0
# 1336  The Man in the Iron Mask            125219                 244.0
# 294    The Wolf of Wall Street            780588                1138.0
# 1364                  J. Edgar            102728                 279.0
# 246                The Aviator            264318                 799.0
# 1909             Marvin's Room             20163                  71.0
# 934                  The Beach            176169                 548.0
# 1046        Revolutionary Road            152591                 414.0
# 1457    The Quick and the Dead             69197                 216.0
# 312          Gangs of New York            314033                1166.0
# 608               Body of Lies            174248                 263.0
# 293              Blood Diamond            400292                 657.0
#
#      language  budget  title_year  imdb_score  movie_facebook_likes  \
# 25    English   200.0      1997.0         7.7                 26000
# 94    English   160.0      2010.0         8.8                175000
# 859   English    52.0      2002.0         8.0                 15000
# 283   English   100.0      2012.0         8.5                199000
# 173   English   135.0      2015.0         8.1                190000
# 431   English    80.0      2010.0         8.1                 53000
# 347   English    90.0      2006.0         8.5                 29000
# 49    English   105.0      2013.0         7.3                115000
# 3025  English   105.0      2013.0         7.3                115000
# 2484  English    14.5      1996.0         6.8                 10000
# 1336  English    35.0      1998.0         6.4                     0
# 294   English   100.0      2013.0         8.2                138000
# 1364  English    35.0      2011.0         6.6                 16000
# 246   English   110.0      2004.0         7.5                     0
# 1909  English    23.0      1996.0         6.7                  1000
# 934   English    50.0      2000.0         6.6                     0
# 1046  English    35.0      2008.0         7.3                     0
# 1457  English    32.0      1995.0         6.4                     0
# 312   English   100.0      2002.0         7.5                     0
# 608   English    70.0      2008.0         7.1                     0
# 293   English   100.0      2006.0         8.0                 14000
#
#           profit
# 25    458.672302
# 94    132.568851
# 859   112.435221
# 283    62.804648
# 173    48.635922
# 431    47.968405
# 347    42.373442
# 49     39.812796
# 3025   39.812796
# 2484   31.838728
# 1336   21.876365
# 294    16.866727
# 1364    2.304950
# 246    -7.391173
# 1909  -10.217492
# 934   -10.221401
# 1046  -12.122192
# 1457  -13.363463
# 312   -22.320362
# 608   -30.619558
# 293   -42.633738

# %%
#Brad_Pitt = # Include all movies in which Brad_Pitt is the lead

Brad_Pitt = new_movies[(new_movies['actor_1_name'] == 'Brad Pitt')]
Brad_Pitt
# Out:
#               director_name  num_critic_for_reviews       gross  \
# 383       Steven Soderbergh                   186.0  183.405771
# 244              Doug Liman                   233.0  186.336103
# 887             Neil Jordan                   120.0  105.264608
# 448              David Ayer                   406.0   85.707116
# 243       Steven Soderbergh                   198.0  125.531634
# 2030  Alejandro G. Iñárritu                   285.0   34.300771
# 2428         Andrew Dominik                   414.0   14.938570
# 2602             Tony Scott                   122.0   12.281500
# 2146    Angelina Jolie Pitt                   131.0    0.531009
# 1397        Terrence Malick                   584.0   13.303319
# 97            David Fincher                   362.0  127.490802
# 646           David Fincher                   315.0   37.023395
# 1608         Andrew Dominik                   273.0    3.904982
# 579     Jean-Jacques Annaud                    76.0   37.901509
# 749         Patrick Gilmore                    98.0   26.288320
# 142       Wolfgang Petersen                   220.0  133.228348
# 367              Tony Scott                   142.0    0.026871
#
#                                                  genres actor_1_name  \
# 383                                      Crime|Thriller    Brad Pitt
# 244                Action|Comedy|Crime|Romance|Thriller    Brad Pitt
# 887                                Drama|Fantasy|Horror    Brad Pitt
# 448                                    Action|Drama|War    Brad Pitt
# 243                                      Crime|Thriller    Brad Pitt
# 2030                                              Drama    Brad Pitt
# 2428                                     Crime|Thriller    Brad Pitt
# 2602                Action|Crime|Drama|Romance|Thriller    Brad Pitt
# 2146                                      Drama|Romance    Brad Pitt
# 1397                                      Drama|Fantasy    Brad Pitt
# 97                                Drama|Fantasy|Romance    Brad Pitt
# 646                                               Drama    Brad Pitt
# 1608              Biography|Crime|Drama|History|Western    Brad Pitt
# 579               Adventure|Biography|Drama|History|War    Brad Pitt
# 749   Adventure|Animation|Comedy|Drama|Family|Fantas...    Brad Pitt
# 142                                           Adventure    Brad Pitt
# 367                               Action|Crime|Thriller    Brad Pitt
#
#                                             movie_title  num_voted_users  \
# 383                                     Ocean's Eleven            402645
# 244                                   Mr. & Mrs. Smith            348861
# 887   Interview with the Vampire: The Vampire Chroni...           239752
# 448                                               Fury            303185
# 243                                     Ocean's Twelve            284852
# 2030                                             Babel            243799
# 2428                               Killing Them Softly            111625
# 2602                                      True Romance            163492
# 2146                                        By the Sea              7976
# 1397                                  The Tree of Life            136367
# 97                 The Curious Case of Benjamin Button            459346
# 646                                         Fight Club           1347461
# 1608  The Assassination of Jesse James by the Coward...           136104
# 579                               Seven Years in Tibet             96385
# 749                   Sinbad: Legend of the Seven Seas             36144
# 142                                               Troy            381672
# 367                                           Spy Game            121259
#
#       num_user_for_reviews language  budget  title_year  imdb_score  \
# 383                  845.0  English    85.0      2001.0         7.8
# 244                  798.0  English   120.0      2005.0         6.5
# 887                  406.0  English    60.0      1994.0         7.6
# 448                  701.0  English    68.0      2014.0         7.6
# 243                  627.0  English   110.0      2004.0         6.4
# 2030                 908.0  English    25.0      2006.0         7.5
# 2428                 369.0  English    15.0      2012.0         6.2
# 2602                 460.0  English    13.0      1993.0         8.0
# 2146                  61.0  English    10.0      2015.0         5.3
# 1397                 975.0  English    32.0      2011.0         6.7
# 97                   822.0  English   150.0      2008.0         7.8
# 646                 2968.0  English    63.0      1999.0         8.8
# 1608                 415.0  English    30.0      2007.0         7.5
# 579                  119.0  English    70.0      1997.0         7.0
# 749                   91.0  English    60.0      2003.0         6.7
# 142                 1694.0  English   175.0      2004.0         7.2
# 367                  361.0  English    92.0      2001.0         7.0
#
#       movie_facebook_likes     profit
# 383                      0  98.405771
# 244                      0  66.336103
# 887                  11000  45.264608
# 448                  82000  17.707116
# 243                      0  15.531634
# 2030                     0   9.300771
# 2428                 20000  -0.061430
# 2602                 15000  -0.718500
# 2146                     0  -9.468991
# 1397                 39000 -18.696681
# 97                   23000 -22.509198
# 646                  48000 -25.976605
# 1608                     0 -26.095018
# 579                      0 -32.098491
# 749                    880 -33.711680
# 142                      0 -41.771652
# 367                      0 -91.973129

# %%
# Write your code for combining the three dataframes here
#Combined = 

Combined=pd.concat([Meryl_Streep,Leo_Caprio, Brad_Pitt])
Combined
# Out:
#               director_name  num_critic_for_reviews       gross  \
# 1322          David Frankel                   208.0  124.732962
# 1471         Sydney Pollack                    66.0   87.100000
# 1132            Nora Ephron                   252.0   94.125426
# 1514          David Frankel                   234.0   63.536011
# 392            Nancy Meyers                   187.0  112.703470
# 2500         Phyllida Lloyd                   331.0   29.959436
# 1784         Stephen Daldry                   174.0   41.597830
# 2793          Robert Altman                   211.0   20.338609
# 1038          Curtis Hanson                    42.0   46.815748
# 1563          Carl Franklin                    64.0   23.209440
# 1390         Robert Redford                   227.0   14.998070
# 25            James Cameron                   315.0  658.672302
# 94        Christopher Nolan                   642.0  292.568851
# 859        Steven Spielberg                   194.0  164.435221
# 283       Quentin Tarantino                   765.0  162.804648
# 173   Alejandro G. Iñárritu                   556.0  183.635922
# 431         Martin Scorsese                   490.0  127.968405
# 347         Martin Scorsese                   352.0  132.373442
# 49             Baz Luhrmann                   490.0  144.812796
# 3025           Baz Luhrmann                   490.0  144.812796
# 2484           Baz Luhrmann                   106.0   46.338728
# 1336        Randall Wallace                    83.0   56.876365
# 294         Martin Scorsese                   606.0  116.866727
# 1364         Clint Eastwood                   392.0   37.304950
# 246         Martin Scorsese                   267.0  102.608827
# 1909             Jerry Zaks                    45.0   12.782508
# 934             Danny Boyle                   118.0   39.778599
# 1046             Sam Mendes                   323.0   22.877808
# 1457              Sam Raimi                    63.0   18.636537
# 312         Martin Scorsese                   233.0   77.679638
# 608            Ridley Scott                   238.0   39.380442
# 293            Edward Zwick                   166.0   57.366262
# 383       Steven Soderbergh                   186.0  183.405771
# 244              Doug Liman                   233.0  186.336103
# 887             Neil Jordan                   120.0  105.264608
# 448              David Ayer                   406.0   85.707116
# 243       Steven Soderbergh                   198.0  125.531634
# 2030  Alejandro G. Iñárritu                   285.0   34.300771
# 2428         Andrew Dominik                   414.0   14.938570
# 2602             Tony Scott                   122.0   12.281500
# 2146    Angelina Jolie Pitt                   131.0    0.531009
# 1397        Terrence Malick                   584.0   13.303319
# 97            David Fincher                   362.0  127.490802
# 646           David Fincher                   315.0   37.023395
# 1608         Andrew Dominik                   273.0    3.904982
# 579     Jean-Jacques Annaud                    76.0   37.901509
# 749         Patrick Gilmore                    98.0   26.288320
# 142       Wolfgang Petersen                   220.0  133.228348
# 367              Tony Scott                   142.0    0.026871
#
#                                                  genres       actor_1_name  \
# 1322                               Comedy|Drama|Romance       Meryl Streep
# 1471                            Biography|Drama|Romance       Meryl Streep
# 1132                            Biography|Drama|Romance       Meryl Streep
# 1514                               Comedy|Drama|Romance       Meryl Streep
# 392                                Comedy|Drama|Romance       Meryl Streep
# 2500                            Biography|Drama|History       Meryl Streep
# 1784                                      Drama|Romance       Meryl Streep
# 2793                                 Comedy|Drama|Music       Meryl Streep
# 1038                    Action|Adventure|Crime|Thriller       Meryl Streep
# 1563                                              Drama       Meryl Streep
# 1390                                 Drama|Thriller|War       Meryl Streep
# 25                                        Drama|Romance  Leonardo DiCaprio
# 94                     Action|Adventure|Sci-Fi|Thriller  Leonardo DiCaprio
# 859                               Biography|Crime|Drama  Leonardo DiCaprio
# 283                                       Drama|Western  Leonardo DiCaprio
# 173                    Adventure|Drama|Thriller|Western  Leonardo DiCaprio
# 431                                    Mystery|Thriller  Leonardo DiCaprio
# 347                                Crime|Drama|Thriller  Leonardo DiCaprio
# 49                                        Drama|Romance  Leonardo DiCaprio
# 3025                                      Drama|Romance  Leonardo DiCaprio
# 2484                                      Drama|Romance  Leonardo DiCaprio
# 1336                                   Action|Adventure  Leonardo DiCaprio
# 294                        Biography|Comedy|Crime|Drama  Leonardo DiCaprio
# 1364                              Biography|Crime|Drama  Leonardo DiCaprio
# 246                                     Biography|Drama  Leonardo DiCaprio
# 1909                                              Drama  Leonardo DiCaprio
# 934                            Adventure|Drama|Thriller  Leonardo DiCaprio
# 1046                                      Drama|Romance  Leonardo DiCaprio
# 1457                            Action|Thriller|Western  Leonardo DiCaprio
# 312                                         Crime|Drama  Leonardo DiCaprio
# 608                               Action|Drama|Thriller  Leonardo DiCaprio
# 293                            Adventure|Drama|Thriller  Leonardo DiCaprio
# 383                                      Crime|Thriller          Brad Pitt
# 244                Action|Comedy|Crime|Romance|Thriller          Brad Pitt
# 887                                Drama|Fantasy|Horror          Brad Pitt
# 448                                    Action|Drama|War          Brad Pitt
# 243                                      Crime|Thriller          Brad Pitt
# 2030                                              Drama          Brad Pitt
# 2428                                     Crime|Thriller          Brad Pitt
# 2602                Action|Crime|Drama|Romance|Thriller          Brad Pitt
# 2146                                      Drama|Romance          Brad Pitt
# 1397                                      Drama|Fantasy          Brad Pitt
# 97                                Drama|Fantasy|Romance          Brad Pitt
# 646                                               Drama          Brad Pitt
# 1608              Biography|Crime|Drama|History|Western          Brad Pitt
# 579               Adventure|Biography|Drama|History|War          Brad Pitt
# 749   Adventure|Animation|Comedy|Drama|Family|Fantas...          Brad Pitt
# 142                                           Adventure          Brad Pitt
# 367                               Action|Crime|Thriller          Brad Pitt
#
#                                             movie_title  num_voted_users  \
# 1322                             The Devil Wears Prada            286178
# 1471                                     Out of Africa             52339
# 1132                                     Julie & Julia             79264
# 1514                                      Hope Springs             34258
# 392                                   It's Complicated             69860
# 2500                                     The Iron Lady             82327
# 1784                                         The Hours            102123
# 2793                          A Prairie Home Companion             19655
# 1038                                    The River Wild             32544
# 1563                                    One True Thing              9283
# 1390                                   Lions for Lambs             41170
# 25                                             Titanic            793059
# 94                                           Inception           1468200
# 859                                Catch Me If You Can            525801
# 283                                   Django Unchained            955174
# 173                                       The Revenant            406020
# 431                                     Shutter Island            786092
# 347                                       The Departed            873649
# 49                                    The Great Gatsby            362912
# 3025                                  The Great Gatsby            362933
# 2484                                    Romeo + Juliet            167750
# 1336                          The Man in the Iron Mask            125219
# 294                            The Wolf of Wall Street            780588
# 1364                                          J. Edgar            102728
# 246                                        The Aviator            264318
# 1909                                     Marvin's Room             20163
# 934                                          The Beach            176169
# 1046                                Revolutionary Road            152591
# 1457                            The Quick and the Dead             69197
# 312                                  Gangs of New York            314033
# 608                                       Body of Lies            174248
# 293                                      Blood Diamond            400292
# 383                                     Ocean's Eleven            402645
# 244                                   Mr. & Mrs. Smith            348861
# 887   Interview with the Vampire: The Vampire Chroni...           239752
# 448                                               Fury            303185
# 243                                     Ocean's Twelve            284852
# 2030                                             Babel            243799
# 2428                               Killing Them Softly            111625
# 2602                                      True Romance            163492
# 2146                                        By the Sea              7976
# 1397                                  The Tree of Life            136367
# 97                 The Curious Case of Benjamin Button            459346
# 646                                         Fight Club           1347461
# 1608  The Assassination of Jesse James by the Coward...           136104
# 579                               Seven Years in Tibet             96385
# 749                   Sinbad: Legend of the Seven Seas             36144
# 142                                               Troy            381672
# 367                                           Spy Game            121259
#
#       num_user_for_reviews language  budget  title_year  imdb_score  \
# 1322                 631.0  English    35.0      2006.0         6.8
# 1471                 200.0  English    31.0      1985.0         7.2
# 1132                 277.0  English    40.0      2009.0         7.0
# 1514                 178.0  English    30.0      2012.0         6.3
# 392                  214.0  English    85.0      2009.0         6.6
# 2500                 350.0  English    13.0      2011.0         6.4
# 1784                 660.0  English    25.0      2002.0         7.6
# 2793                 280.0  English    10.0      2006.0         6.8
# 1038                  69.0  English    45.0      1994.0         6.3
# 1563                 112.0  English    30.0      1998.0         7.0
# 1390                 298.0  English    35.0      2007.0         6.2
# 25                  2528.0  English   200.0      1997.0         7.7
# 94                  2803.0  English   160.0      2010.0         8.8
# 859                  667.0  English    52.0      2002.0         8.0
# 283                 1193.0  English   100.0      2012.0         8.5
# 173                 1188.0  English   135.0      2015.0         8.1
# 431                  964.0  English    80.0      2010.0         8.1
# 347                 2054.0  English    90.0      2006.0         8.5
# 49                   753.0  English   105.0      2013.0         7.3
# 3025                 753.0  English   105.0      2013.0         7.3
# 2484                 506.0  English    14.5      1996.0         6.8
# 1336                 244.0  English    35.0      1998.0         6.4
# 294                 1138.0  English   100.0      2013.0         8.2
# 1364                 279.0  English    35.0      2011.0         6.6
# 246                  799.0  English   110.0      2004.0         7.5
# 1909                  71.0  English    23.0      1996.0         6.7
# 934                  548.0  English    50.0      2000.0         6.6
# 1046                 414.0  English    35.0      2008.0         7.3
# 1457                 216.0  English    32.0      1995.0         6.4
# 312                 1166.0  English   100.0      2002.0         7.5
# 608                  263.0  English    70.0      2008.0         7.1
# 293                  657.0  English   100.0      2006.0         8.0
# 383                  845.0  English    85.0      2001.0         7.8
# 244                  798.0  English   120.0      2005.0         6.5
# 887                  406.0  English    60.0      1994.0         7.6
# 448                  701.0  English    68.0      2014.0         7.6
# 243                  627.0  English   110.0      2004.0         6.4
# 2030                 908.0  English    25.0      2006.0         7.5
# 2428                 369.0  English    15.0      2012.0         6.2
# 2602                 460.0  English    13.0      1993.0         8.0
# 2146                  61.0  English    10.0      2015.0         5.3
# 1397                 975.0  English    32.0      2011.0         6.7
# 97                   822.0  English   150.0      2008.0         7.8
# 646                 2968.0  English    63.0      1999.0         8.8
# 1608                 415.0  English    30.0      2007.0         7.5
# 579                  119.0  English    70.0      1997.0         7.0
# 749                   91.0  English    60.0      2003.0         6.7
# 142                 1694.0  English   175.0      2004.0         7.2
# 367                  361.0  English    92.0      2001.0         7.0
#
#       movie_facebook_likes      profit
# 1322                     0   89.732962
# 1471                     0   56.100000
# 1132                 13000   54.125426
# 1514                     0   33.536011
# 392                      0   27.703470
# 2500                 18000   16.959436
# 1784                     0   16.597830
# 2793                   683   10.338609
# 1038                     0    1.815748
# 1563                   592   -6.790560
# 1390                     0  -20.001930
# 25                   26000  458.672302
# 94                  175000  132.568851
# 859                  15000  112.435221
# 283                 199000   62.804648
# 173                 190000   48.635922
# 431                  53000   47.968405
# 347                  29000   42.373442
# 49                  115000   39.812796
# 3025                115000   39.812796
# 2484                 10000   31.838728
# 1336                     0   21.876365
# 294                 138000   16.866727
# 1364                 16000    2.304950
# 246                      0   -7.391173
# 1909                  1000  -10.217492
# 934                      0  -10.221401
# 1046                     0  -12.122192
# 1457                     0  -13.363463
# 312                      0  -22.320362
# 608                      0  -30.619558
# 293                  14000  -42.633738
# 383                      0   98.405771
# 244                      0   66.336103
# 887                  11000   45.264608
# 448                  82000   17.707116
# 243                      0   15.531634
# 2030                     0    9.300771
# 2428                 20000   -0.061430
# 2602                 15000   -0.718500
# 2146                     0   -9.468991
# 1397                 39000  -18.696681
# 97                   23000  -22.509198
# 646                  48000  -25.976605
# 1608                     0  -26.095018
# 579                      0  -32.098491
# 749                    880  -33.711680
# 142                      0  -41.771652
# 367                      0  -91.973129

# %%
# Write your code for grouping the combined dataframe here

combined_new = Combined.groupby('actor_1_name')

# %%
# Write the code for finding the mean of critic reviews and audience reviews here

combined_new['num_critic_for_reviews','num_user_for_reviews'].mean()
# Out:
# <ipython-input-53-756f933aa1bb>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   combined_new['num_critic_for_reviews','num_user_for_reviews'].mean()
#                    num_critic_for_reviews  num_user_for_reviews
# actor_1_name
# Brad Pitt                      245.000000            742.352941
# Leonardo DiCaprio              330.190476            914.476190
# Meryl Streep                   181.454545            297.181818

# %% [markdown]
# #### <font color='red'>Question 8: Which actor is highest rated among the three actors according to the user reviews? </font>
# -  <font color='red'>Meryl Streep</font>
# -  <font color='red'>Leonardo DiCaprio</font>
# -  <font color='red'>Brad Pitt</font>

# %%
## Write your code here

print ("Actor with the highest rated of user reviews{}: ", combined_new['num_user_for_reviews'].mean().sort_values(ascending=False))
# Out:
# Actor with the highest rated of user reviews{}:  actor_1_name
# Leonardo DiCaprio    914.476190
# Brad Pitt            742.352941
# Meryl Streep         297.181818
# Name: num_user_for_reviews, dtype: float64

# %% [markdown]
# #### <font color='red'>Question 9: Which actor is highest rated among the three actors according to the critics?</font>
# -  <font color='red'>Meryl Streep</font>
# -  <font color='red'>Leonardo DiCaprio</font>
# -  <font color='red'>Brad Pitt</font>

# %%
## Write your code here

print ("the Mean of audience reviews : ",combined_new['num_critic_for_reviews'].mean().sort_values(ascending=False))
# Out:
# the Mean of audience reviews :  actor_1_name
# Leonardo DiCaprio    330.190476
# Brad Pitt            245.000000
# Meryl Streep         181.454545
# Name: num_critic_for_reviews, dtype: float64

# %% [markdown]
# #### <font color='red'>Question 10: Which movie starting with the letter A, has the 3rd highest profit?</font>
# -  <font color='red'>Austin Powers: The Spy Who Shagged Me</font>
# -  <font color='red'>Avatar</font>
# -  <font color='red'>Avengers: Age of Ultron</font>

# %%
## Write your code here

movie_A = new_movies[(new_movies['movie_title'].str.startswith('A'))]
movie_A = movie_A.sort_values(by = 'profit', ascending = False)
movie_A
# Out:
#         director_name  num_critic_for_reviews       gross  \
# 0       James Cameron                   723.0  760.505847
# 769    Clint Eastwood                   490.0  350.123553
# 7         Joss Whedon                   635.0  458.991599
# 1622     Ron Clements                   124.0  217.350219
# 1314        Jay Roach                   199.0  205.399422
# ...               ...                     ...         ...
# 3109     Frank Coraci                   188.0   24.004159
# 102       James Bobin                   218.0   76.846624
# 2525     Costa-Gavras                    69.0    0.274299
# 109      Oliver Stone                   248.0   34.293771
# 2990  Katsuhiro Ôtomo                   150.0    0.439162
#
#                                                  genres     actor_1_name  \
# 0                       Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 769         Action|Biography|Drama|History|Thriller|War   Bradley Cooper
# 7                               Action|Adventure|Sci-Fi  Chris Hemsworth
# 1622  Adventure|Animation|Comedy|Family|Fantasy|Musi...   Robin Williams
# 1314                      Action|Adventure|Comedy|Crime      Muse Watson
# ...                                                 ...              ...
# 3109                            Action|Adventure|Comedy    Jim Broadbent
# 102                            Adventure|Family|Fantasy      Johnny Depp
# 2525                          Biography|Crime|Drama|War   Sebastian Koch
# 109   Action|Adventure|Biography|Drama|History|Roman...  Anthony Hopkins
# 2990                            Action|Animation|Sci-Fi     Mitsuo Iwata
#
#                                  movie_title  num_voted_users  \
# 0                                    Avatar            886204
# 769                         American Sniper            325264
# 7                   Avengers: Age of Ultron            462669
# 1622                                Aladdin            260939
# 1314  Austin Powers: The Spy Who Shagged Me            181225
# ...                                      ...              ...
# 3109            Around the World in 80 Days             68722
# 102         Alice Through the Looking Glass             21352
# 2525                                  Amen.             11077
# 109                               Alexander            138863
# 2990                                  Akira            106160
#
#       num_user_for_reviews  language  budget  title_year  imdb_score  \
# 0                   3054.0   English   237.0      2009.0         7.9
# 769                  916.0   English    58.8      2014.0         7.3
# 7                   1117.0   English   250.0      2015.0         7.5
# 1622                 244.0   English    28.0      1992.0         8.0
# 1314                 784.0   English    33.0      1999.0         6.6
# ...                    ...       ...     ...         ...         ...
# 3109                 191.0   English   110.0      2004.0         5.8
# 102                  131.0   English   170.0      2016.0         6.4
# 2525                  55.0   English   103.0      2002.0         7.3
# 109                 1390.0   English   155.0      2004.0         5.5
# 2990                 430.0  Japanese  1100.0      1988.0         8.1
#
#       movie_facebook_likes       profit
# 0                    33000   523.505847
# 769                 112000   291.323553
# 7                   118000   208.991599
# 1622                     0   189.350219
# 1314                     0   172.399422
# ...                    ...          ...
# 3109                     0   -85.995841
# 102                  30000   -93.153376
# 2525                     0  -102.725701
# 109                      0  -120.706229
# 2990                     0 -1099.560838
#
# [240 rows x 14 columns]

# %%
print ("The movie starting with the letter A, has the 3rd highest profit : ",movie_A['movie_title'].iloc[2])
# Out:
# The movie starting with the letter A, has the 3rd highest profit :  Avengers: Age of Ultron

# %% [markdown]
# #### <font color='red'>Question 11: Among the movies starting with the letter A, who has the highest imdb score?</font>
# -  <font color='red'>American History X</font>
# -  <font color='red'>Apocalypse Now</font>
# -  <font color='red'>Avengers: Age of Ultron</font>

# %%
## Write your code here

movie_A = new_movies[(new_movies['movie_title'].str.startswith('A'))]
movie_A = movie_A.sort_values(by = 'imdb_score', ascending = False)
movie_A
# Out:
#              director_name  num_critic_for_reviews       gross  \
# 2826             Tony Kaye                   162.0    6.712241
# 2893          Ridley Scott                   392.0   78.900000
# 1467  Francis Ford Coppola                   261.0   78.800000
# 1222    Jean-Pierre Jeunet                   242.0   33.201661
# 3684        Asghar Farhadi                   354.0    7.098492
# ...                    ...                     ...         ...
# 427          Mike Mitchell                    91.0  133.103929
# 2118          David Zucker                    45.0    7.001720
# 479            Peter Hyams                   113.0    1.891821
# 2874         Arthur Hiller                    29.0    0.015447
# 2127              Uwe Boll                   148.0    5.132655
#
#                                                genres  \
# 2826                                      Crime|Drama
# 2893                                    Horror|Sci-Fi
# 1467                                        Drama|War
# 1222                                   Comedy|Romance
# 3684                                    Drama|Mystery
# ...                                               ...
# 427   Adventure|Animation|Comedy|Family|Fantasy|Music
# 2118                                   Comedy|Fantasy
# 479           Action|Adventure|Horror|Sci-Fi|Thriller
# 2874                                           Comedy
# 2127                                    Horror|Sci-Fi
#
#                    actor_1_name                                 movie_title  \
# 2826               Ethan Suplee                         American History X
# 2893               Tom Skerritt                                      Alien
# 1467              Harrison Ford                             Apocalypse Now
# 1222          Mathieu Kassovitz                                     Amélie
# 3684            Shahab Hosseini                               A Separation
# ...                         ...                                         ...
# 427                 Amy Poehler       Alvin and the Chipmunks: Chipwrecked
# 2118              Chriss Anglin                          An American Carol
# 479               David Oyelowo                         A Sound of Thunder
# 2874                  Eric Idle  An Alan Smithee Film: Burn Hollywood Burn
# 2127  Catherine Lough Haggquist                          Alone in the Dark
#
#       num_voted_users  num_user_for_reviews language  budget  title_year  \
# 2826           782437                1420.0  English     7.5      1998.0
# 2893           563827                1110.0  English    11.0      1979.0
# 1467           450676                 983.0  English    31.5      1979.0
# 1222           534262                1314.0   French    77.0      2001.0
# 3684           151812                 264.0  Persian     0.5      2011.0
# ...               ...                   ...      ...     ...         ...
# 427             22838                  56.0  English    75.0      2011.0
# 2118             8560                 205.0  English    12.0      2008.0
# 479             16474                 301.0  English    52.0      2005.0
# 2874             2971                  85.0  English    10.0      1997.0
# 2127            37626                 521.0  English    20.0      2005.0
#
#       imdb_score  movie_facebook_likes     profit
# 2826         8.6                 35000  -0.787759
# 2893         8.5                 23000  67.900000
# 1467         8.5                 19000  47.300000
# 1222         8.4                 39000 -43.798339
# 3684         8.4                 48000   6.598492
# ...          ...                   ...        ...
# 427          4.4                     0  58.103929
# 2118         4.3                   797  -4.998280
# 479          4.2                   785 -50.108179
# 2874         3.5                    89  -9.984553
# 2127         2.3                  1000 -14.867345
#
# [240 rows x 14 columns]

# %%
movieA = movie_A.nlargest(1, 'imdb_score', keep='first')
top1 = movieA[['movie_title','imdb_score']]
print ("The movie starting with the letter A, has the highest imdb_score : ")
top1
# Out:
# The movie starting with the letter A, has the highest imdb_score :
#               movie_title  imdb_score
# 2826  American History X          8.6

# %% [markdown]
# #### <font color='red'>Question 12: Among the movies that '*Joss Whedon*' has directed, which of them made the highest profit?</font>
# -  <font color='red'>Serenity</font>
# -  <font color='red'>The Avengers</font>
# -  <font color='red'>Avengers: Age of Ultron</font>

# %%
## Write your code here
movie_JS = new_movies[(new_movies['director_name'].str.contains('Joss Whedon'))]
movie_JS = movie_JS.sort_values(by = 'profit', ascending = False)
movie_JS
# Out:
#      director_name  num_critic_for_reviews       gross  \
# 16     Joss Whedon                   703.0  623.279547
# 7      Joss Whedon                   635.0  458.991599
# 1253   Joss Whedon                   276.0   25.335935
#
#                                 genres     actor_1_name  \
# 16             Action|Adventure|Sci-Fi  Chris Hemsworth
# 7              Action|Adventure|Sci-Fi  Chris Hemsworth
# 1253  Action|Adventure|Sci-Fi|Thriller     Adam Baldwin
#
#                    movie_title  num_voted_users  num_user_for_reviews  \
# 16               The Avengers            995415                1722.0
# 7     Avengers: Age of Ultron            462669                1117.0
# 1253                 Serenity            242599                1594.0
#
#      language  budget  title_year  imdb_score  movie_facebook_likes  \
# 16    English   220.0      2012.0         8.1                123000
# 7     English   250.0      2015.0         7.5                118000
# 1253  English    40.0      2005.0         8.0                 14000
#
#           profit
# 16    403.279547
# 7     208.991599
# 1253  -14.664065

# %%
print ("The movies that 'Joss Whedon' has directed, which of them made the highest profit : ",movie_JS['movie_title'].iloc[0])
# Out:
# The movies that 'Joss Whedon' has directed, which of them made the highest profit :  The Avengers

# %% [markdown]
# #### <font color='red'>Question 13: Among the movies that were released in the year '*2007*' & '*2008*', which of them had the 2nd highest imdb score?</font>
# -  <font color='red'>The Dark Knight</font>
# -  <font color='red'>WALL·E</font>
# -  <font color='red'>No End in Sight</font>
# -  <font color='red'>Into the Wild</font>

# %%
## Write your code here
movie_year = new_movies.loc[new_movies['title_year'].between(2007,2008)]
movie_year = movie_year.sort_values(by= 'imdb_score', ascending = False)
movie_year
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 64    Christopher Nolan                   645.0  533.316061
# 56       Andrew Stanton                   421.0  223.806889
# 3513   Charles Ferguson                    79.0    1.430185
# 1732     Clint Eastwood                   366.0  148.085755
# 2070          Sean Penn                   274.0   18.352454
# ...                 ...                     ...         ...
# 3122        Fred Savage                    52.0   13.235267
# 1546    Jason Friedberg                   111.0   38.232624
# 2019    Jason Friedberg                   112.0   39.737645
# 3049   Don Michael Paul                    25.0    5.694308
# 2085    Jason Friedberg                   111.0   14.174654
#
#                                  genres       actor_1_name  \
# 64          Action|Crime|Drama|Thriller     Christian Bale
# 56    Adventure|Animation|Family|Sci-Fi  John Ratzenberger
# 3513                    Documentary|War     Campbell Scott
# 1732                              Drama     Clint Eastwood
# 2070          Adventure|Biography|Drama    Kristen Stewart
# ...                                 ...                ...
# 3122                      Comedy|Family      Lochlyn Munro
# 1546                             Comedy     Carmen Electra
# 2019                   Adventure|Comedy    David Carradine
# 3049                       Comedy|Sport      Jeffrey Jones
# 2085                             Comedy     Carmen Electra
#
#              movie_title  num_voted_users  num_user_for_reviews language  \
# 64      The Dark Knight           1676169                4667.0  English
# 56               WALL·E            718837                1043.0  English
# 3513    No End in Sight              7314                  55.0  English
# 1732        Gran Torino            561773                 871.0  English
# 2070      Into the Wild            426359                 760.0  English
# ...                  ...              ...                   ...      ...
# 3122     Daddy Day Camp             12339                  32.0  English
# 1546  Meet the Spartans             88518                 409.0  English
# 2019         Epic Movie             89687                 666.0  English
# 3049  Who's Your Caddy?             13815                  46.0  English
# 2085     Disaster Movie             74945                 359.0  English
#
#       budget  title_year  imdb_score  movie_facebook_likes      profit
# 64     185.0      2008.0         9.0                 37000  348.316061
# 56     180.0      2008.0         8.4                 16000   43.806889
# 3513     2.0      2007.0         8.3                     0   -0.569815
# 1732    33.0      2008.0         8.2                 28000  115.085755
# 2070    15.0      2007.0         8.2                 76000    3.352454
# ...      ...         ...         ...                   ...         ...
# 3122     6.0      2007.0         2.9                   256    7.235267
# 1546    30.0      2008.0         2.7                     0    8.232624
# 2019    20.0      2007.0         2.3                     0   19.737645
# 3049     7.0      2007.0         2.0                   446   -1.305692
# 2085    25.0      2008.0         1.9                     0  -10.825346
#
# [343 rows x 14 columns]

# %%
movie_year = movie_year.nlargest(2, 'imdb_score', keep='first')
top2 = movie_year[['movie_title','imdb_score']]
print ("movies that were released in the year '2007' & '2008', which of them had the 2nd highest imdb score : ")
top2
# Out:
# movies that were released in the year '2007' & '2008', which of them had the 2nd highest imdb score :
#          movie_title  imdb_score
# 64  The Dark Knight          9.0
# 56           WALL·E          8.4
